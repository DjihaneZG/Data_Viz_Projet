# %%
import sweetviz as sv
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/full_2020.csv")
# Out:
# c:\users\djiha\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (8,10,12,14,16,17,18,20,22,35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2020-1    2020-01-07                   1           Vente
# 1      2020-2    2020-01-02                   1           Vente
# 2      2020-2    2020-01-02                   1           Vente
# 3      2020-2    2020-01-02                   1           Vente
# 4      2020-2    2020-01-02                   1           Vente
#
#    valeur_fonciere  adresse_numero adresse_suffixe        adresse_nom_voie  \
# 0           8000.0             NaN             NaN                FORTUNAT
# 1           2175.0             NaN             NaN  TERRES DES CINQ SAULES
# 2           2175.0             NaN             NaN      BOIS DU CHAMP RION
# 3           2175.0             NaN             NaN             EN COROBERT
# 4           2175.0             NaN             NaN  TERRES DES CINQ SAULES
#
#   adresse_code_voie  code_postal  ... type_local surface_reelle_bati  \
# ...

# %%
#Cleaning
df.drop(["lot1_numero", "lot2_numero", "lot3_numero", "lot4_numero", "lot5_numero", "lot1_surface_carrez", "lot2_surface_carrez", "lot3_surface_carrez", "lot4_surface_carrez", "lot5_surface_carrez", "adresse_suffixe", "ancien_nom_commune", "ancien_code_commune", "ancien_id_parcelle", "code_nature_culture", "nature_culture_speciale", "code_nature_culture_speciale", "numero_volume"], axis=1)
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2020-1    2020-01-07                   1           Vente
# 1              2020-2    2020-01-02                   1           Vente
# 2              2020-2    2020-01-02                   1           Vente
# 3              2020-2    2020-01-02                   1           Vente
# 4              2020-2    2020-01-02                   1           Vente
# ...               ...           ...                 ...             ...
# 2459555  2020-1075291    2020-12-16                   1           Vente
# 2459556  2020-1075291    2020-12-16                   1           Vente
# 2459557  2020-1075291    2020-12-16                   1           Vente
# 2459558  2020-1075291    2020-12-16                   1           Vente
# 2459559  2020-1075292    2020-10-08                   1    Adjudication
#
#          valeur_fonciere  adresse_numero        adresse_nom_voie  \
# ...

# %%
df['adresse_code_voie'] = df['adresse_code_voie'].astype(str)
df['code_commune'] = df['code_commune'].astype(str)
df['code_departement'] = df['code_departement'].astype(str)
df['numero_volume'] = df['numero_volume'].astype(str)

# %%
type(df['longitude'][3])
# Out:
# numpy.float64

# %%
#my_report = sv.analyze(df)
#my_report.show_html()

# %%
#pre-processing
#We will work on a sample of our data set to be more efficient in our work
df_sample = df.sample(n=100000, random_state=1)

# %%
df_sample = df_sample.drop(["lot1_numero", "lot2_numero", "lot3_numero", "lot4_numero", "lot5_numero", "lot1_surface_carrez", "lot2_surface_carrez", "lot3_surface_carrez", "lot4_surface_carrez", "lot5_surface_carrez", "adresse_suffixe", "ancien_nom_commune", "ancien_code_commune", "ancien_id_parcelle", "code_nature_culture", "nature_culture_speciale", "code_nature_culture_speciale", "numero_volume"], axis=1)

# %%
df_sample.head()
# Out:
#          id_mutation date_mutation  numero_disposition nature_mutation  \
# 1767872  2020-745116    2020-04-29                   1           Vente
# 983851   2020-409856    2020-09-28                   1           Vente
# 1883682  2020-798938    2020-01-17                   1           Vente
# 2243518  2020-956983    2020-01-14                   1           Vente
# 971775   2020-405213    2020-04-16                   1           Vente
#
#          valeur_fonciere  adresse_numero        adresse_nom_voie  \
# 1767872         480000.0             NaN         LE VERT BUISSON
# 983851          600000.0           135.0     AV DE LA LIBERATION
# 1883682         124250.0             5.0     ALL DU HAUT DU PARC
# 2243518         317500.0            38.0  RUE D ESTIENNE D ORVES
# 971775           76932.0           465.0       CHE DES COLLERETS
#
#         adresse_code_voie  code_postal code_commune  ...     id_parcelle  \
# ...

# %%
df_sample.tail()
# Out:
#          id_mutation date_mutation  numero_disposition nature_mutation  \
# 276370   2020-121141    2020-07-11                   1           Vente
# 908029   2020-379895    2020-06-08                   1           Vente
# 2161427  2020-916470    2020-10-16                   1           Vente
# 1791487  2020-756902    2020-06-09                   1           Vente
# 417058   2020-175347    2020-09-14                   1           Vente
#
#          valeur_fonciere  adresse_numero  adresse_nom_voie adresse_code_voie  \
# 276370          211000.0             NaN      LA GALOTERIE              B003
# 908029            4000.0             NaN             ECOLE              B031
# 2161427          45000.0             NaN        LES RACATS              B050
# 1791487          26282.0             NaN          L EGLISE              B001
# 417058            9828.0            18.0  LOT KASTELL DOUR              A022
#
#          code_postal code_commune  ...     id_parcelle nombre_lots  \
# ...

# %%
#data transformation

# %%
df_sample['adresse_code_voie'] = df_sample['adresse_code_voie'].astype(str)
df_sample['code_commune'] = df_sample['code_commune'].astype(str)
df_sample['code_departement'] = df_sample['code_departement'].astype(str)

# %%
df_sample["code_departement"]
# Out:
# 1767872    76
# 983851     42
# 1883682    78
# 2243518    92
# 971775     42
#            ..
# 276370     14
# 908029     40
# 2161427    89
# 1791487    76
# 417058     22
# Name: code_departement, Length: 100000, dtype: object

# %%
def count_rows(rows): 
    return len(rows)

# %%
by_departement = df.groupby('code_departement').apply(count_rows)
by_departement.nlargest(15)
# Out:
# code_departement
# 33    91383
# 59    84457
# 44    81754
# 77    66274
# 35    63357
# 6     58686
# 75    54130
# 78    53077
# 69    51630
# 85    49734
# 13    49004
# 49    47582
# 95    46746
# 30    45227
# 93    43135
# dtype: int64

# %%
#Quelles sont les départements ayant le plus grand nombre de transactions immobilières ? 
plt.plot(by_departement.nlargest(15))
#ne pas oublier les label

# %%
plt.figure(figsize = (30, 15))
plt.bar(range(1, 16), by_departement.nlargest(15))
plt.xticks(range(1, 16), by_departement.nlargest(15).index)
plt.xlabel('Departement')
plt.ylabel('Nombre de transaction immobilière')
plt.title('Frequency by DoM - Uber - April 2014')
# Out:
# Text(0.5, 1.0, 'Frequency by DoM - Uber - April 2014')

# %%
#Quelles sont les communes ou/et départements ayant le plus grand nombre de transactions immobilières en 2020? (heat zone in France)
#plt.plot(by_departement)
plt.pie(by_departement.nlargest(6), explode = [0.4, 0.2, 0.1, 0, 0, 0])
plt.show()

# %% [raw]
# #What are the cities that have experienced the biggest price increase this year? the last 4 years?
